# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from data_loading.dow30_small_loader import data_loading
from model.portfolio import Portfolio

df_open, df_high, df_low, df_close, \
df_adj_close, df_volume, df_return = data_loading()

a = Portfolio(df_open, df_high, df_low, df_close, \
              df_adj_close, df_volume, df_return)
a.make_my_account_equal()

plt.plot(df_adj_close.index, df_adj_close['XOM']/df_adj_close['XOM'][0], 'b')
plt.plot(df_adj_close.index, a.my_account_final['TOTAL'], 'r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from data_loading.dow30_loader import data_loading
from model.portfolio import Portfolio

df_open, df_high, df_low, df_close, \
df_adj_close, df_volume, df_return = data_loading()

a = Portfolio(df_open, df_high, df_low, df_close, \
              df_adj_close, df_volume, df_return)
a.make_my_account_equal()

plt.plot(df_adj_close.index, df_adj_close['XOM']/df_adj_close['XOM'][0], 'b')
plt.plot(df_adj_close.index, a.my_account_final['TOTAL'], 'r')
plt.show()

# %%
from model.portfolio import Portfolio
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_dir = 'data/dow30'
benchmark = 'SPY'
start = "2017-01-01"
end = "2017-12-31"

p = Portfolio(data_dir, benchmark=benchmark, start=start, end=end)
p.data_loading()
p.compute_normalized_adj_close()
p.compute_daily_return()

# %%
p.normalized_adj_close['WMT'].plot()

# %%
p.daily_return['WMT'].plot()

# %%
start = "2017-02-01"
end = "2017-02-28"
p.plot_risk_return(start, end)

# %%
adj_close, daily_return, sigma, mu = p.equal_portfolio()
adj_close.plot()
print(np.sqrt(sigma), mu)
# Out:
# 0.062391423912550245 0.22371790658206292
